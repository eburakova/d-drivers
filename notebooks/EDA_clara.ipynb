# %%
import pandas as pd
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_colwidth', None)
pd.plotting.register_matplotlib_converters()
import pygwalker as pyg

import numpy as np
import seaborn as sns
import missingno as mgn

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import matplotlib.pyplot as plt

pio.templates.default = "simple_white"

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv('/Users/clara/Desktop/neuefische/d-drivers/data/data_features.csv')
#df.drop([])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6815 entries, 0 to 6814
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   page_id                 6815 non-null   int64
#  1   n_days                  6815 non-null   int64
#  2   url                     6815 non-null   object
#  3   n_urls                  6815 non-null   int64
#  4   no_versions             6815 non-null   int64
#  5   age                     6815 non-null   int64
#  6   last_publish_date       6815 non-null   object
#  7   publish_date_min        6815 non-null   object
#  8   word_count              6815 non-null   float64
#  9   classification_product  6815 non-null   object
#  10  classification_type     6815 non-null   object
#  11  page_name               6815 non-null   object
#  12  title                   6815 non-null   object
#  13  last_author             6815 non-null   object
#  14  external_clicks         6815 non-null   float64
#  15  external_impressions    6815 non-null   float64
#  16  likes_n_days            6815 non-null   float64
#  17  dislikes_n_days         6815 non-null   float64
#  18  video_play              6815 non-null   float64
#  19  page_impressions        6815 non-null   float64
#  20  clickouts               6815 non-null   float64
#  21  ctr                     6815 non-null   float64
#  22  h1                      6815 non-null   object
#  23  scraped_author          6815 non-null   object
#  24  date_scraped            6815 non-null   object
#  25  abstract                6808 non-null   object
#  26  scraped_word_count      6815 non-null   int64
#  27  meta_title              6815 non-null   object
#  28  meta_description        6815 non-null   object
#  29  meta_image_url          6815 non-null   object
#  30  media_type              6815 non-null   object
#  31  page_img_size           5066 non-null   object
#  32  merged_url              6815 non-null   object
#  33  meta_title_len          6815 non-null   int64
#  34  meta_desc_len           6815 non-null   int64
#  35  h1_len                  6815 non-null   int64
#  36  abstract_len            6808 non-null   float64
#  37  merged_url_len          6815 non-null   int64
# dtypes: float64(10), int64(10), object(18)
# memory usage: 2.0+ MB

# %%
# Summarize all target variables in a list
target = ['crt', 'external_clicks', 'external_impressions']

# Summarize all numeric variables in a list
num_variables = df.select_dtypes(include=[np.number]).columns.tolist()
# columns_to_remove = ['external_clicks', 'external_impressions', 'ctr']
# for col in columns_to_remove:
#     num_variables.remove(col)

# %%
# Compute the correlation matrix
corr_matrix = df[num_variables].corr()

# Print the correlation matrix
print(corr_matrix)

# Create heatmap of correlation matrix
fig = px.imshow(corr_matrix, color_continuous_scale='RdBu', title='Correlation Matrix')
fig.show()
# Out:
#                        page_id    n_days    n_urls  no_versions       age
# page_id               1.000000 -0.300763 -0.227742    -0.167048 -0.175386  \
# n_days               -0.300763  1.000000  0.615208     0.624697  0.041246
# n_urls               -0.227742  0.615208  1.000000     0.929609 -0.024247
# no_versions          -0.167048  0.624697  0.929609     1.000000  0.066316
# age                  -0.175386  0.041246 -0.024247     0.066316  1.000000
# word_count           -0.086368  0.162702  0.185634     0.195596 -0.313156
# external_clicks       0.002478  0.238998  0.293525     0.289466 -0.023107
# external_impressions  0.001997  0.267615  0.324947     0.324785 -0.028377
# likes_n_days         -0.046476  0.104402  0.123044     0.104603  0.012987
# dislikes_n_days      -0.039736  0.054709  0.089376     0.064154  0.004068
# video_play            0.006177  0.276891  0.313687     0.310121 -0.035206
# page_impressions      0.009198  0.309372  0.334653     0.337487 -0.045051
# clickouts            -0.058957  0.473494  0.494711     0.553420 -0.009441
# ctr                  -0.188644  0.080662 -0.004324    -0.022485  0.080295
# scraped_word_count   -0.382895  0.317928  0.251357     0.249505  0.026716
# meta_title_len        0.128259 -0.085379 -0.133782    -0.114050  0.015657
# meta_desc_len         0.048708 -0.039672 -0.075214    -0.116526 -0.197312
# h1_len                0.036908  0.006077  0.026831     0.027202  0.019977
# abstract_len         -0.082623  0.071993  0.084147     0.098524 -0.026051
# merged_url_len        0.003588 -0.021901 -0.045449    -0.059414  0.015586
#
#                       word_count  external_clicks  external_impressions
# page_id                -0.086368         0.002478              0.001997  \
# n_days                  0.162702         0.238998              0.267615
# n_urls                  0.185634         0.293525              0.324947
# no_versions             0.195596         0.289466              0.324785
# age                    -0.313156        -0.023107             -0.028377
# word_count              1.000000         0.035535              0.044973
# external_clicks         0.035535         1.000000              0.989970
# external_impressions    0.044973         0.989970              1.000000
# likes_n_days            0.055622         0.412528              0.394297
# dislikes_n_days         0.039406         0.344655              0.308884
# video_play              0.047537         0.926818              0.923087
# page_impressions        0.057033         0.920344              0.918439
# clickouts               0.156360         0.116950              0.159428
# ctr                    -0.163384         0.069412              0.050389
# scraped_word_count      0.631193        -0.004927              0.001695
# meta_title_len         -0.094299         0.015345              0.010097
# meta_desc_len          -0.020082        -0.058736             -0.063580
# h1_len                 -0.036092         0.017798              0.017813
# abstract_len            0.173824         0.018597              0.022194
# merged_url_len         -0.056029        -0.037516             -0.039153
#
#                       likes_n_days  dislikes_n_days  video_play
# page_id                  -0.046476        -0.039736    0.006177  \
# n_days                    0.104402         0.054709    0.276891
# n_urls                    0.123044         0.089376    0.313687
# no_versions               0.104603         0.064154    0.310121
# age                       0.012987         0.004068   -0.035206
# word_count                0.055622         0.039406    0.047537
# external_clicks           0.412528         0.344655    0.926818
# external_impressions      0.394297         0.308884    0.923087
# likes_n_days              1.000000         0.943195    0.421122
# dislikes_n_days           0.943195         1.000000    0.337093
# video_play                0.421122         0.337093    1.000000
# page_impressions          0.380777         0.296992    0.980012
# clickouts                 0.073518         0.009561    0.129588
# ctr                       0.023928         0.023781    0.096035
# scraped_word_count        0.032529         0.019701   -0.011218
# meta_title_len            0.010496         0.012796    0.021384
# meta_desc_len            -0.025262        -0.008584   -0.050868
# h1_len                    0.014983         0.012938    0.025068
# abstract_len              0.014546         0.003850    0.027665
# merged_url_len           -0.009878        -0.000560   -0.036238
#
#                       page_impressions  clickouts       ctr
# page_id                       0.009198  -0.058957 -0.188644  \
# n_days                        0.309372   0.473494  0.080662
# n_urls                        0.334653   0.494711 -0.004324
# no_versions                   0.337487   0.553420 -0.022485
# age                          -0.045051  -0.009441  0.080295
# word_count                    0.057033   0.156360 -0.163384
# external_clicks               0.920344   0.116950  0.069412
# external_impressions          0.918439   0.159428  0.050389
# likes_n_days                  0.380777   0.073518  0.023928
# dislikes_n_days               0.296992   0.009561  0.023781
# video_play                    0.980012   0.129588  0.096035
# page_impressions              1.000000   0.158748  0.109343
# clickouts                     0.158748   1.000000 -0.009740
# ctr                           0.109343  -0.009740  1.000000
# scraped_word_count           -0.005248   0.181940 -0.017277
# meta_title_len                0.016779  -0.059416  0.050522
# meta_desc_len                -0.048727  -0.027032  0.046941
# h1_len                        0.022373   0.023072  0.043659
# abstract_len                  0.034281   0.060320  0.005169
# merged_url_len               -0.039163  -0.018469  0.045501
#
#                       scraped_word_count  meta_title_len  meta_desc_len
# page_id                        -0.382895        0.128259       0.048708  \
# n_days                          0.317928       -0.085379      -0.039672
# n_urls                          0.251357       -0.133782      -0.075214
# no_versions                     0.249505       -0.114050      -0.116526
# age                             0.026716        0.015657      -0.197312
# word_count                      0.631193       -0.094299      -0.020082
# external_clicks                -0.004927        0.015345      -0.058736
# external_impressions            0.001695        0.010097      -0.063580
# likes_n_days                    0.032529        0.010496      -0.025262
# dislikes_n_days                 0.019701        0.012796      -0.008584
# video_play                     -0.011218        0.021384      -0.050868
# page_impressions               -0.005248        0.016779      -0.048727
# clickouts                       0.181940       -0.059416      -0.027032
# ctr                            -0.017277        0.050522       0.046941
# scraped_word_count              1.000000       -0.162182      -0.093669
# meta_title_len                 -0.162182        1.000000       0.121648
# meta_desc_len                  -0.093669        0.121648       1.000000
# h1_len                         -0.033379        0.795216       0.033206
# abstract_len                    0.170543       -0.019156       0.009927
# merged_url_len                 -0.029420        0.463235       0.097060
#
#                         h1_len  abstract_len  merged_url_len
# page_id               0.036908     -0.082623        0.003588
# n_days                0.006077      0.071993       -0.021901
# n_urls                0.026831      0.084147       -0.045449
# no_versions           0.027202      0.098524       -0.059414
# age                   0.019977     -0.026051        0.015586
# word_count           -0.036092      0.173824       -0.056029
# external_clicks       0.017798      0.018597       -0.037516
# external_impressions  0.017813      0.022194       -0.039153
# likes_n_days          0.014983      0.014546       -0.009878
# dislikes_n_days       0.012938      0.003850       -0.000560
# video_play            0.025068      0.027665       -0.036238
# page_impressions      0.022373      0.034281       -0.039163
# clickouts             0.023072      0.060320       -0.018469
# ctr                   0.043659      0.005169        0.045501
# scraped_word_count   -0.033379      0.170543       -0.029420
# meta_title_len        0.795216     -0.019156        0.463235
# meta_desc_len         0.033206      0.009927        0.097060
# h1_len                1.000000      0.004531        0.444874
# abstract_len          0.004531      1.000000       -0.025121
# merged_url_len        0.444874     -0.025121        1.000000

# %%
# Compute the correlation matrix
corr_matrix = df[num_variables].corr()

# Set the threshold for significant correlations
threshold = 0.5  # You can adjust this threshold as needed

# Create a mask to filter out insignificant correlations
mask = np.abs(corr_matrix) >= threshold
corr_matrix_filtered = corr_matrix[mask]

# Print the filtered correlation matrix
print(corr_matrix_filtered)

# Create heatmap of filtered correlation matrix
fig = px.imshow(corr_matrix_filtered, color_continuous_scale='RdBu', title='Significant Correlations (absolute value >= 0.5)')
fig.show()
# Out:
#                       page_id    n_days    n_urls  no_versions  age
# page_id                   1.0       NaN       NaN          NaN  NaN  \
# n_days                    NaN  1.000000  0.615208     0.624697  NaN
# n_urls                    NaN  0.615208  1.000000     0.929609  NaN
# no_versions               NaN  0.624697  0.929609     1.000000  NaN
# age                       NaN       NaN       NaN          NaN  1.0
# word_count                NaN       NaN       NaN          NaN  NaN
# external_clicks           NaN       NaN       NaN          NaN  NaN
# external_impressions      NaN       NaN       NaN          NaN  NaN
# likes_n_days              NaN       NaN       NaN          NaN  NaN
# dislikes_n_days           NaN       NaN       NaN          NaN  NaN
# video_play                NaN       NaN       NaN          NaN  NaN
# page_impressions          NaN       NaN       NaN          NaN  NaN
# clickouts                 NaN       NaN       NaN     0.553420  NaN
# ctr                       NaN       NaN       NaN          NaN  NaN
# scraped_word_count        NaN       NaN       NaN          NaN  NaN
# meta_title_len            NaN       NaN       NaN          NaN  NaN
# meta_desc_len             NaN       NaN       NaN          NaN  NaN
# h1_len                    NaN       NaN       NaN          NaN  NaN
# abstract_len              NaN       NaN       NaN          NaN  NaN
# merged_url_len            NaN       NaN       NaN          NaN  NaN
#
#                       word_count  external_clicks  external_impressions
# page_id                      NaN              NaN                   NaN  \
# n_days                       NaN              NaN                   NaN
# n_urls                       NaN              NaN                   NaN
# no_versions                  NaN              NaN                   NaN
# age                          NaN              NaN                   NaN
# word_count              1.000000              NaN                   NaN
# external_clicks              NaN         1.000000              0.989970
# external_impressions         NaN         0.989970              1.000000
# likes_n_days                 NaN              NaN                   NaN
# dislikes_n_days              NaN              NaN                   NaN
# video_play                   NaN         0.926818              0.923087
# page_impressions             NaN         0.920344              0.918439
# clickouts                    NaN              NaN                   NaN
# ctr                          NaN              NaN                   NaN
# scraped_word_count      0.631193              NaN                   NaN
# meta_title_len               NaN              NaN                   NaN
# meta_desc_len                NaN              NaN                   NaN
# h1_len                       NaN              NaN                   NaN
# abstract_len                 NaN              NaN                   NaN
# merged_url_len               NaN              NaN                   NaN
#
#                       likes_n_days  dislikes_n_days  video_play
# page_id                        NaN              NaN         NaN  \
# n_days                         NaN              NaN         NaN
# n_urls                         NaN              NaN         NaN
# no_versions                    NaN              NaN         NaN
# age                            NaN              NaN         NaN
# word_count                     NaN              NaN         NaN
# external_clicks                NaN              NaN    0.926818
# external_impressions           NaN              NaN    0.923087
# likes_n_days              1.000000         0.943195         NaN
# dislikes_n_days           0.943195         1.000000         NaN
# video_play                     NaN              NaN    1.000000
# page_impressions               NaN              NaN    0.980012
# clickouts                      NaN              NaN         NaN
# ctr                            NaN              NaN         NaN
# scraped_word_count             NaN              NaN         NaN
# meta_title_len                 NaN              NaN         NaN
# meta_desc_len                  NaN              NaN         NaN
# h1_len                         NaN              NaN         NaN
# abstract_len                   NaN              NaN         NaN
# merged_url_len                 NaN              NaN         NaN
#
#                       page_impressions  clickouts  ctr  scraped_word_count
# page_id                            NaN        NaN  NaN                 NaN  \
# n_days                             NaN        NaN  NaN                 NaN
# n_urls                             NaN        NaN  NaN                 NaN
# no_versions                        NaN    0.55342  NaN                 NaN
# age                                NaN        NaN  NaN                 NaN
# word_count                         NaN        NaN  NaN            0.631193
# external_clicks               0.920344        NaN  NaN                 NaN
# external_impressions          0.918439        NaN  NaN                 NaN
# likes_n_days                       NaN        NaN  NaN                 NaN
# dislikes_n_days                    NaN        NaN  NaN                 NaN
# video_play                    0.980012        NaN  NaN                 NaN
# page_impressions              1.000000        NaN  NaN                 NaN
# clickouts                          NaN    1.00000  NaN                 NaN
# ctr                                NaN        NaN  1.0                 NaN
# scraped_word_count                 NaN        NaN  NaN            1.000000
# meta_title_len                     NaN        NaN  NaN                 NaN
# meta_desc_len                      NaN        NaN  NaN                 NaN
# h1_len                             NaN        NaN  NaN                 NaN
# abstract_len                       NaN        NaN  NaN                 NaN
# merged_url_len                     NaN        NaN  NaN                 NaN
#
#                       meta_title_len  meta_desc_len    h1_len  abstract_len
# page_id                          NaN            NaN       NaN           NaN  \
# n_days                           NaN            NaN       NaN           NaN
# n_urls                           NaN            NaN       NaN           NaN
# no_versions                      NaN            NaN       NaN           NaN
# age                              NaN            NaN       NaN           NaN
# word_count                       NaN            NaN       NaN           NaN
# external_clicks                  NaN            NaN       NaN           NaN
# external_impressions             NaN            NaN       NaN           NaN
# likes_n_days                     NaN            NaN       NaN           NaN
# dislikes_n_days                  NaN            NaN       NaN           NaN
# video_play                       NaN            NaN       NaN           NaN
# page_impressions                 NaN            NaN       NaN           NaN
# clickouts                        NaN            NaN       NaN           NaN
# ctr                              NaN            NaN       NaN           NaN
# scraped_word_count               NaN            NaN       NaN           NaN
# meta_title_len              1.000000            NaN  0.795216           NaN
# meta_desc_len                    NaN            1.0       NaN           NaN
# h1_len                      0.795216            NaN  1.000000           NaN
# abstract_len                     NaN            NaN       NaN           1.0
# merged_url_len                   NaN            NaN       NaN           NaN
#
#                       merged_url_len
# page_id                          NaN
# n_days                           NaN
# n_urls                           NaN
# no_versions                      NaN
# age                              NaN
# word_count                       NaN
# external_clicks                  NaN
# external_impressions             NaN
# likes_n_days                     NaN
# dislikes_n_days                  NaN
# video_play                       NaN
# page_impressions                 NaN
# clickouts                        NaN
# ctr                              NaN
# scraped_word_count               NaN
# meta_title_len                   NaN
# meta_desc_len                    NaN
# h1_len                           NaN
# abstract_len                     NaN
# merged_url_len                   1.0

# %%
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-000615d1b06ffb07DNX7PU6F9mvQoWCr" style="height: auto">\n    <head>…
