# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

import missingno as mgn

# %%
df = pd.read_excel('../data/discover_2024-03-26.xlsx', sheet_name='data')
df.columns = [col.lower() for col in df.columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132846 entries, 0 to 132845
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   page_efahrer_id             132846 non-null  int64
#  1   date                        132846 non-null  datetime64[ns]
#  2   published_at                42111 non-null   datetime64[ns]
#  3   publish_date_equal_to_date  132846 non-null  object
#  4   page_canonical_url          132846 non-null  object
#  5   page_name                   132846 non-null  object
#  6   classification_product      132191 non-null  object
#  7   classification_type         132191 non-null  object
#  8   title                       132846 non-null  object
#  9   page_author                 132846 non-null  object
#  10  daily_likes                 33623 non-null   float64
#  11  daily_dislikes              27291 non-null   float64
#  12  word_count                  41639 non-null   float64
#  13  video_play                  132070 non-null  float64
#  14  impressions                 132070 non-null  float64
#  15  discover_clicks             132070 non-null  float64
#  16  discover_impressions        132070 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(7)
# memory usage: 17.2+ MB

# %%
titles = pd.read_csv('../data/real_title.csv', header=None, names=['real_title'])
titles # the order is the same as in the original dataframe!
# Out:
#                                                                               real_title
# 0               Krasse Strompreis-Erhöhungen: Diese Bescheide müssen Sie nicht hinnehmen
# 1                        In 2""5 Stunden voll: Dieser Solargenerator lädt rasend schnell
# 2              Gedrosselter Strom für E-Autos und Wärmepumpen: Das plant die Netzagentur
# 3                              Heizdefekt im Dacia Spring: So lösen Besitzer das Problem
# 4                Bis zu 12 Stunden ohne Strom: Nachbarland zeigt drei mögliche Szenarien
# ...                                                                                  ...
# 132610                 Schritt-für-Schritt erklärt: So melden Sie Ihr Balkonkraftwerk an
# 132611                         Verivox Vergleichsportal aktuell zu günstigen Konditionen
# 132612      Neuer Speicher für Balkonkraftwerke kommt: Frühbucher bekommen dicken Rabatt
# 132613          VW ID. Buzz Cargo im Leasing günstig: Elektro-Bulli kann richtig buckeln
# 132614  Er passt sich an den Körper an: Deutscher Zulieferer zeigt neuen Sicherheitsgurt
#
# [132615 rows x 1 columns]

# %%
old_df = pd.read_excel('../data/discover_0123_0324.xlsx', sheet_name='data')
old_df.columns = [col.lower() for col in old_df.columns]
old_df.head()
# Out:
#    page_efahrer_id       date published_at publish_date_equal_to_date
# 0          1010629 2023-01-01          NaT                          N  \
# 1           108566 2023-01-01          NaT                          N
# 2          1010799 2023-01-01          NaT                          N
# 3          1010717 2023-01-01   2023-01-01                          Y
# 4           109654 2023-01-01          NaT                          N
#
#                                                                                                   page_canonical_url
# 0         https://efahrer.chip.de/news/unwirksame-preiserhoehung-wer-hier-kunde-ist-muss-sie-nicht-hinnehmen_1010629  \
# 1      https://efahrer.chip.de/news/laedt-super-schnell-wir-haben-den-top-solargenerator-von-jackery-getestet_108566
# 2    https://efahrer.chip.de/news/gedrosselter-strom-fuer-e-autos-und-waermepumpen-das-plant-die-netzagentur_1010799
# 3  https://efahrer.chip.de/news/heizung-faellt-im-dacia-spring-aus-wie-fahrer-das-problem-aktis-76394-loesen_1010717
# 4   https://efahrer.chip.de/news/bis-zu-12-stunden-ohne-strom-schweizer-bereiten-sich-auf-energie-notfall-vor_109654
#
#                                                                                         page_name
# 0  efa-1010629 | StromerhÃ¶hungs-Brief gar nicht legal? Diese 50 Stromversorger arbeiten unsauber  \
# 1                 efa-108566 | Stromausfall mitten in Deutschland: Solargenerator rettete den Tag
# 2       efa-1010799 | 10 Stunden und lÃ¤nger - Netzagentur plant Schnarch-Laden fÃ¼r Elektroautos
# 3         efa-1010717 | Dacia Spring hat massives Heizproblem: Besitzer wollen nicht mehr frieren
# 4                 efa-109654 | 12 Stunden Strom-Ausfall pro Tag: Reiches Nachbarland wappnet sich
#
#   classification_product classification_type
# 0                Energie                News  \
# 1         Solargenerator                News
# 2                 E-Auto                News
# 3                 E-Auto                News
# 4                Energie                News
#
#                                                                                                                                                                                  title
# 0                                                                                                Unwirksame PreiserhÃ¶hung: Wer hier Kunde ist, muss sie nicht hinnehmen - EFAHRER.com  \
# 1                                                                                             LÃ¤dt super schnell: Wir haben den Top-Solargenerator von Jackery getestet - EFAHRER.com
# 2                                                                                            Gedrosselter Strom fÃ¼r E-Autos und WÃ¤rmepumpen: Das plant die Netzagentur - EFAHRER.com
# 3                                                                                          Heizung fÃ¤llt im Dacia Spring aus: Wie Fahrer das Problem Aktis 76394 lÃ¶sen - EFAHRER.com
# 4  Ð”Ð¾ 12 Ñ‡Ð°ÑÐ¾Ð² Ð±ÐµÐ· ÑÐ»ÐµÐºÑ‚Ñ€Ð¸Ñ‡ÐµÑÑ‚Ð²Ð°: ÑˆÐ²ÐµÐ¹Ñ†Ð°Ñ€Ñ†Ñ‹ Ð³Ð¾Ñ‚Ð¾Ð²ÑÑ‚ÑÑ Ðº ÑÐ½ÐµÑ€Ð³ÐµÑ‚Ð¸Ñ‡ÐµÑÐºÐ¾Ð¹ Ñ‡Ñ€ÐµÐ·Ð²Ñ‹Ñ‡Ð°Ð¹Ð½Ð¾Ð¹ ÑÐ¸Ñ‚ÑƒÐ°Ñ†Ð¸Ð¸ - EFAHRER.com
#
#         page_author  daily_likes  daily_dislikes  word_count  video_play
# 0   Vanessa Finkler          NaN             NaN         NaN         0.0  \
# 1  Sebastian Barsch          NaN             NaN         NaN       130.0
# 2      FOCUS Online          NaN             NaN         NaN       491.0
# 3      Tobias Stahl     800000.0        200000.0       914.0       140.0
# 4       Aslan Berse          NaN             NaN         NaN       133.0
#
#    clickouts  discover_clicks  discover_impressions
# 0        0.0           1385.0               12410.0
# 1        2.0            143.0                8083.0
# 2        2.0            803.0               13542.0
# 3        1.0            266.0               18289.0
# 4        0.0            312.0                6018.0

# %%
old_df = pd.concat((old_df, titles), axis=1)

# %%
old_df_ = old_df[['page_efahrer_id', 'date', 'page_canonical_url', 'real_title']]

# %%
df_merged = pd.merge(left=df, right=old_df_, on=['page_efahrer_id', 'date', 'page_canonical_url'], how='left')
df_merged
# Out:
#         page_efahrer_id       date published_at publish_date_equal_to_date
# 0               1010803 2023-01-02          NaT                          N  \
# 1               1010592 2023-01-02          NaT                          N
# 2               1010719 2023-01-05          NaT                          N
# 3               1010727 2023-01-05          NaT                          N
# 4               1010557 2023-01-02   2023-01-02                          Y
# ...                 ...        ...          ...                        ...
# 133199          1010297 2023-11-17   2023-11-17                          Y
# 133200          1014887 2023-12-31   2023-12-13                          N
# 133201           105946 2024-01-18   2024-01-16                          N
# 133202          1014127 2023-08-17          NaT                          N
# 133203          1011976 2024-01-19   2024-01-16                          N
#
#                                                                                                               page_canonical_url
# 0       https://efahrer.chip.de/news/tariferhoehungen-und-thg-praemie-ladesaeulenbetreiber-ziehen-kunden-ueber-den-tisch_1010803  \
# 1                                  https://efahrer.chip.de/news/das-logo-von-alfa-romeo-wofuer-stehen-schlange-und-kreuz_1010592
# 2             https://efahrer.chip.de/news/titel-ist-zurueck-in-deutschland-forscher-entwickeln-effizienteste-solarzelle_1010719
# 3              https://efahrer.chip.de/news/entlastungen-fuer-heizoel-kunden-wer-keinen-antrag-stellt-bekommt-gar-nichts_1010727
# 4                https://efahrer.chip.de/news/solaranlage-auch-fuer-mieter-das-sind-die-besten-modelle-fuer-ihren-balkon_1010557
# ...                                                                                                                          ...
# 133199         https://efahrer.chip.de/news/hammer-preis-fuer-hammer-auto-hyundai-ioniq-6-schon-fuer-200-euro-im-leasing_1010297
# 133200       https://efahrer.chip.de/news/aldi-verkauft-rueckfahrkamera-fuers-auto-der-selbsteinbau-soll-ein-klacks-sein_1014887
# 133201        https://efahrer.chip.de/news/guenstiges-e-auto-trotz-praemien-aus-bei-diesen-neuwagen-sparen-sie-am-meisten_105946
# 133202                      https://efahrer.chip.de/news/urlaubshoelle-in-italien-deutscher-strandet-mit-billigem-e-auto_1014127
# 133203      https://efahrer.chip.de/news/heizkoerper-ventilatoren-was-die-klemm-luefter-unter-heizungen-wirklich-bringen_1011976
#
#                                                                                              page_name
# 0       efa-1010803 | Tariferhöhungen und THG-Prämie: Ladesäulenbetreiber ziehen Kunden über den Tisch  \
# 1                                           efa-1010592 | Alfa Romeo: Was bedeuten Schlange und Kreuz?
# 2           efa-1010719 | Rennen um die effizienteste Solarzelle: Deutsche holen sich den Titel zurück
# 3       efa-1010727 | Antrag stellen oder leer ausgehen: Diese Entlastung ist für Heizöl-Kunden geplan
# 4                                    efa-1010557 | Balkonkraftwerk kaufen: Das sind die besten Modelle
# ...                                                                                                ...
# 133199                                                              efa-1010297 | Hyundai IONIQ 6 Deal
# 133200     efa-1014887 | Aldi verkauft Rückfahrkamera fürs Auto: Der Selbsteinbau soll ein Klacks sein
# 133201      efa-105946 | E-Autos mit kurzer Lieferzeit: Fiat 500e, Polestar 2, Renault Twingo und mehr
# 133202                    efa-1014127 | Urlaubshölle in Italien: Deutsche stranden mit billigem E-Auto
# 133203    efa-1011976 | Hausbesitzer testet Heizkörperbooster mit Wärmepumpe: Mit eindeutigem Ergebnis
#
#        classification_product classification_type
# 0                         THG                News  \
# 1                        Auto                News
# 2                Solaranlagen                News
# 3                     Energie            Ratgeber
# 4             Balkonkraftwerk        Kaufberatung
# ...                       ...                 ...
# 133199                 E-Auto                Deal
# 133200                Zubehör                Deal
# 133201                 E-Auto                Deal
# 133202                 E-Auto                News
# 133203                Energie                Deal
#
#                                                                                     title
# 0        Tariferhöhungen und THG-Prämie: Ladesäulenbetreiber ziehen Kunden über den Tisch  \
# 1                                            Alfa Romeo: Was bedeuten Schlange und Kreuz?
# 2            Rennen um die effizienteste Solarzelle: Deutsche holen sich den Titel zurück
# 3        Antrag stellen oder leer ausgehen: Diese Entlastung ist für Heizöl-Kunden geplan
# 4                                     Balkonkraftwerk kaufen: Das sind die besten Modelle
# ...                                                                                   ...
# 133199                                                               Hyundai IONIQ 6 Deal
# 133200      Aldi verkauft Rückfahrkamera fürs Auto: Der Selbsteinbau soll ein Klacks sein
# 133201      E-Autos mit kurzer Lieferzeit: Fiat 500e, Polestar 2, Renault Twingo und mehr
# 133202                     Urlaubshölle in Italien: Deutsche stranden mit billigem E-Auto
# 133203     Hausbesitzer testet Heizkörperbooster mit Wärmepumpe: Mit eindeutigem Ergebnis
#
#               page_author  daily_likes  daily_dislikes  word_count
# 0            Karl Lüdecke          NaN             NaN         NaN  \
# 1             Karl Müller          NaN             NaN         NaN
# 2             Aslan Berse          NaN             NaN         NaN
# 3                    CHIP          NaN             NaN         NaN
# 4          Eva Goldschald         17.0             1.0      1513.0
# ...                   ...          ...             ...         ...
# 133199         Lisa Brack          0.0             0.0       725.0
# 133200    Vanessa Finkler          0.0             0.0       535.0
# 133201    Benjamin Dizdar          0.0             0.0      2142.0
# 133202    Vanessa Finkler          NaN             NaN         NaN
# 133203  Redaktion EFAHRER          0.0             0.0       859.0
#
#         video_play  impressions  discover_clicks  discover_impressions
# 0           1261.0       1375.0           1301.0               20323.0  \
# 1            286.0        298.0            164.0                1493.0
# 2            156.0        300.0            303.0                4912.0
# 3             16.0         55.0          14009.0               92422.0
# 4            174.0        128.0           6494.0              114984.0
# ...            ...          ...              ...                   ...
# 133199         1.0          1.0            905.0               12463.0
# 133200         0.0          1.0             95.0                1048.0
# 133201         0.0          1.0             10.0                 106.0
# 133202         0.0          1.0           5820.0               83900.0
# 133203         0.0          1.0           1481.0               31154.0
#
#                                                                                real_title
# 0                 Neueste Förderung für E-Autos: Konzerne profitieren"" Autofahrer zahlen
# 1                               Das Logo von Alfa Romeo: Wofür stehen Schlange und Kreuz?
# 2           Titel ist zurück in Deutschland: Forscher entwickeln effizienteste Solarzelle
# 3       Entlastungen für Heizöl-Kunden: Wer keinen Antrag stellt"" geht komplett leer aus
# 4                                         Balkonkraftwerk kaufen: Die besten Modelle 2024
# ...                                                                                   ...
# 133199                                                   Hyundai Ioniq 6 ab rund 180 Euro
# 133200     Aldi bringt Rückfahrkamera für alle Autos: Top-Preis und kinderleichter Einbau
# 133201                                 Hier gibt's bis zu 40 Prozent auf Ihren E-Neuwagen
# 133202           Wenn der Italien-Urlaub zum Albtraum wird: Deutscher strandet mit E-Auto
# 133203                 Lüfter am Heizkörper: So viel Effizienz bringen die simplen Geräte
#
# [133204 rows x 18 columns]

# %%
df.head(20)

# %% [markdown]
# The first article looks completely differently nowadays!

# %%
df[df['title'].str.contains("Neueste Förderung")]

# %%
df.set_index('page_efahrer_id').loc[1010803]

# %% [markdown]
# WORD_COUNT	VIDEO_PLAY	CLICKOUTS

# %%
mgn.matrix(df.sort_values(['page_efahrer_id', 'date', 'page_name']));

# %%
mgn.dendrogram(df.sort_values(['page_efahrer_id', 'date', 'page_name']));

# %%
mgn.heatmap(df)

# %%
df.isna().sum()

# %%
counts = df.groupby(["page_efahrer_id"]).count()
counts.query("title > 2").iloc[:, 0]

# %% [markdown]
# ## Check uniqness of the attribute

# %%
df[["page_efahrer_id", "classification_product", "classification_type"]].drop_duplicates()\
    .groupby("page_efahrer_id").count().max() #.value_counts()

# %%
df.classification_product.unique()

# %%
df.classification_type.unique()

# %%
df.set_index("page_efahrer_id").loc[1018632] #.PAGE_AUTHOR.unique()

# %% [markdown]
# ### `WORD_COUNT`

# %%
df.word_count.describe()

# %%
df.word_count.hist(bins=50);

# %% [markdown]
# looks like no anomalies

# %%
df[["page_canonical_url", "word_count"]].query("word_count > 3000")

# %%
df[["page_efahrer_id", "word_count"]].sort_values("page_efahrer_id").tail(30)

# %%
df[df.word_count.isna() & ~df.published_at.isna()]

# %%
art_unique_wcnts = df.value_counts(["page_efahrer_id", "word_count"])
art_unique_wcnts.to_frame().rename({'count': 'n_article_occurances'}, axis=1)

# %%
art_unique_wcnts = df.value_counts(["page_efahrer_id", "word_count"])
art_unique_wcnts = art_unique_wcnts.to_frame().rename({'count': 'n_article_occurances'}, axis=1)
art_unique_wcnts.reset_index()

# %%
art_unique_wcnts

# %%
diff_word_counts = art_unique_wcnts.to_frame().reset_index().value_counts() # .to_frame()

# %%
diff_word_counts

# %%
df.nunique()

# %% [markdown]
# ### `VIDEO_PLAY`

# %%
df[df.video_play.isna()].isna().sum()

# %%
df.video_play.describe()

# %%
df.query("video_play >= 700000")

# %%
df.shape

# %%
print(f"""
      Broken:  {df.query("video_play >= 703621").shape}, 
      Normal:  {df.query("video_play < 703621").shape}, 
      Missing: {df[df.video_play.isna()].shape}
""")

# %%
import seaborn as sns
import datetime
now = datetime.datetime.now()
sns.scatterplot(x=pd.to_timedelta(now - df["date"]).dt.days, y=df["video_play"])

# %% [markdown]
# ---

# %%
# unique ids

scraping = df[['page_efahrer_id', 'page_canonical_url']].drop_duplicates()
scraping

# %%
scraping = scraping.to_frame()

# creating the dummy columns that will be populated with the scraped data
scraping['H1'] = 'dummy'
scraping['last_update_date'] = 'today'
scraping['abstract'] = 'null'

scraping = scraping.set_index('page_efahrer_id')

scraping

# %%
## Do actual scraping

i=0
for row_idx in scraping.index:
    scraping.loc[row_idx, 'H1'] = ##the header
    scraping.loc[row_idx, 'last_update_date'] = ##the last update time element
    scraping.loc[row_idx, 'abstract'] = ##find a clever way to extract the abstract?
    i+=1
    if i==10: 
        scraping.to_csv('../data/temp_scraped.csv')
        i=0
