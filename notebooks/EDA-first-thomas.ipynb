# %% [markdown]
# # D-Drivers Capstone project (file of Thomas)
#
# ## Content
#
# 1. Prepare Environment
# 2. Load data
# 3. EDA + first Insights + Preprocessing + further Insights
# 4. Conclusion

# %% [markdown]
# # 1. Prepare Environment

# %% [markdown]
# - create virtual environment with requirenments_dev.txt
# - add `data/`and `.DS_Store` to .gitignore
#
# <details><summary>
# Click here for a details...
# </summary>
#
# ```bash
# pyenv local 3.11.3
# python -m venv .venv
# source .venv/bin/activate
# pip install --upgrade pip
# pip install -r requirements_dev.txt
# ```
# </details>

# %%
import pandas as pd

# Charting
import plotly.express as px

# %% [markdown]
# # 2. Load data

# %%
data_file = 'discover_2024-03-26.xlsx'
file_path = '../data/' + data_file
file_path
# Out:
# '../data/discover_2024-03-26.xlsx'

# %%
df = pd.read_excel(file_path, sheet_name='data')

# %% [markdown]
# # 3. EDA + first insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132846 entries, 0 to 132845
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   PAGE_EFAHRER_ID             132846 non-null  int64
#  1   DATE                        132846 non-null  datetime64[ns]
#  2   PUBLISHED_AT                42111 non-null   datetime64[ns]
#  3   PUBLISH_DATE_EQUAL_TO_DATE  132846 non-null  object
#  4   PAGE_CANONICAL_URL          132846 non-null  object
#  5   PAGE_NAME                   132846 non-null  object
#  6   CLASSIFICATION_PRODUCT      132191 non-null  object
#  7   CLASSIFICATION_TYPE         132191 non-null  object
#  8   TITLE                       132846 non-null  object
#  9   PAGE_AUTHOR                 132846 non-null  object
#  10  DAILY_LIKES                 33623 non-null   float64
#  11  DAILY_DISLIKES              27291 non-null   float64
#  12  WORD_COUNT                  41639 non-null   float64
#  13  VIDEO_PLAY                  132070 non-null  float64
#  14  IMPRESSIONS                 132070 non-null  float64
#  15  DISCOVER_CLICKS             132070 non-null  float64
#  16  DISCOVER_IMPRESSIONS        132070 non-null  float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(7)
# memory usage: 17.2+ MB

# %%
df.isna().sum()
# Out:
# PAGE_EFAHRER_ID                    0
# DATE                               0
# PUBLISHED_AT                   90735
# PUBLISH_DATE_EQUAL_TO_DATE         0
# PAGE_CANONICAL_URL                 0
# PAGE_NAME                          0
# CLASSIFICATION_PRODUCT           655
# CLASSIFICATION_TYPE              655
# TITLE                              0
# PAGE_AUTHOR                        0
# DAILY_LIKES                    99223
# DAILY_DISLIKES                105555
# WORD_COUNT                     91207
# VIDEO_PLAY                       776
# IMPRESSIONS                      776
# DISCOVER_CLICKS                  776
# DISCOVER_IMPRESSIONS             776
# dtype: int64

# %%
# keep raw data for later
df_raw = df.copy()

# %%
df['PAGE_EFAHRER_ID'].unique().size
# Out:
# 6899

# %% [markdown]
# --> use VS Code Add-on "Data Wrangler (Preview) for visually exploring data by clicking on "Open 'df'" below `df.head()`

# %%
df.head()
# Out:
#    PAGE_EFAHRER_ID       DATE PUBLISHED_AT PUBLISH_DATE_EQUAL_TO_DATE
# 0          1010803 2023-01-02          NaT                          N  \
# 1          1010592 2023-01-02          NaT                          N
# 2          1010719 2023-01-05          NaT                          N
# 3          1010727 2023-01-05          NaT                          N
# 4          1010557 2023-01-02   2023-01-02                          Y
#
#                                   PAGE_CANONICAL_URL
# 0  https://efahrer.chip.de/news/tariferhoehungen-...  \
# 1  https://efahrer.chip.de/news/das-logo-von-alfa...
# 2  https://efahrer.chip.de/news/titel-ist-zurueck...
# 3  https://efahrer.chip.de/news/entlastungen-fuer...
# 4  https://efahrer.chip.de/news/solaranlage-auch-...
#
#                                            PAGE_NAME CLASSIFICATION_PRODUCT
# 0  efa-1010803 | Tariferhöhungen und THG-Prämie: ...                    THG  \
# 1  efa-1010592 | Alfa Romeo: Was bedeuten Schlang...                   Auto
# 2  efa-1010719 | Rennen um die effizienteste Sola...           Solaranlagen
# 3  efa-1010727 | Antrag stellen oder leer ausgehe...                Energie
# 4  efa-1010557 | Balkonkraftwerk kaufen: Das sind...        Balkonkraftwerk
#
#   CLASSIFICATION_TYPE                                              TITLE
# 0                News   Tariferhöhungen und THG-Prämie: Ladesäulenbet...  \
# 1                News       Alfa Romeo: Was bedeuten Schlange und Kreuz?
# 2                News   Rennen um die effizienteste Solarzelle: Deuts...
# 3            Ratgeber   Antrag stellen oder leer ausgehen: Diese Entl...
# 4        Kaufberatung   Balkonkraftwerk kaufen: Das sind die besten M...
#
#       PAGE_AUTHOR  DAILY_LIKES  DAILY_DISLIKES  WORD_COUNT  VIDEO_PLAY
# 0    Karl Lüdecke          NaN             NaN         NaN      1261.0  \
# 1     Karl Müller          NaN             NaN         NaN       286.0
# 2     Aslan Berse          NaN             NaN         NaN       156.0
# 3            CHIP          NaN             NaN         NaN        16.0
# 4  Eva Goldschald         17.0             1.0      1513.0       174.0
#
#    IMPRESSIONS  DISCOVER_CLICKS  DISCOVER_IMPRESSIONS
# 0       1375.0           1301.0               20323.0
# 1        298.0            164.0                1493.0
# 2        300.0            303.0                4912.0
# 3         55.0          14009.0               92422.0
# 4        128.0           6494.0              114984.0

# %% [markdown]
# ## 3.1 DRAFT charts

# %%
df_filtered = df[df['year'] == 2024]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 df_filtered = df[df['year'] == 2024]
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/.virtualenvs/d-drivers/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'year'

# %%
# yearly_counts = df.groupby(['yr_built', 'historic_house']).size().reset_index(name='counts')
fig = px.bar(df_filtered, 
             x="date", 
             y="discover_clicks", 
             # text_auto=True, 
             color='is_weekend',
             title="clicks by day")
fig.update_layout(
    xaxis_title='date',
    yaxis_title="clicks"
)
fig.show()

# %% [markdown]
# ## 3.2. Preprocessing
# - lowering all columns
# - add date artefacts (year, month, day of week, is_wekend)
# - mask target columns
# - how to deal with NULL values in likes and dislikes?

# %%
columns = [col.lower() for col in df.columns]
df.columns = columns

# %%
# add coloum day_of_week  (Monday=0, Sunday=6)
df['day_of_week'] = df['date'].dt.dayofweek

# add column is_weekend (True for Sat. and Sun.)
df['is_weekend'] = df['day_of_week'].apply(lambda x: True if x >5 else False)

# add column year
df['year'] = df['date'].dt.year

# add column month
df['month'] = df['date'].dt.month

# replace date column as date to replace datetime column
df['date'] = df['date'].dt.date

# %% [markdown]
# ## 3.3 EDA with whole team

# %%
counts = df.groupby(['page_efahrer_id', 'date', 'title', 'page_name', 'page_canonical_url', 'classification_type', 'classification_product', 'page_author']).count().describe()
# counts.query('publish_date_equal_to_date > 1')
counts
# Out:
#         published_at  publish_date_equal_to_date    daily_likes
# count  131890.000000               131890.000000  131890.000000  \
# mean        0.318045                    1.000129       0.254159
# std         0.465979                    0.011353       0.435633
# min         0.000000                    1.000000       0.000000
# 25%         0.000000                    1.000000       0.000000
# 50%         0.000000                    1.000000       0.000000
# 75%         1.000000                    1.000000       1.000000
# max         2.000000                    2.000000       2.000000
#
#        daily_dislikes     word_count     video_play      clickouts
# count   131890.000000  131890.000000  131890.000000  131890.000000  \
# mean         0.206286       0.314467       0.994283       0.994283
# std          0.404845       0.464566       0.076986       0.076986
# min          0.000000       0.000000       0.000000       0.000000
# 25%          0.000000       0.000000       1.000000       1.000000
# 50%          0.000000       0.000000       1.000000       1.000000
# 75%          0.000000       1.000000       1.000000       1.000000
# max          2.000000       2.000000       2.000000       2.000000
#
#        discover_clicks  discover_impressions    day_of_week     is_weekend
# count    131890.000000         131890.000000  131890.000000  131890.000000  \
# mean          0.994283              0.994283       1.000129       1.000129
# std           0.076986              0.076986       0.011353       0.011353
# min           0.000000              0.000000       1.000000       1.000000
# 25%           1.000000              1.000000       1.000000       1.000000
# 50%           1.000000              1.000000       1.000000       1.000000
# 75%           1.000000              1.000000       1.000000       1.000000
# max           2.000000              2.000000       2.000000       2.000000
#
#             datetime
# count  131890.000000
# mean        1.000129
# std         0.011353
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000

# %%
df['page_name'].value_counts()
# Out:
# page_name
# efa-1014301 | Diese PV-Anlage kommt in die Steckdose: Leistung Ã¼bertrifft Balkonkraftwerke          566
# efa-105259 | E-Auto fÃ¼r 65 Euro: Hier kommt der Billig-Deal fÃ¼r den Elektro-Dacia                  561
# efa-1012150 | Komplette Solaranlage fÃ¼r 10.000 Euro: Das mÃ¼ssen Sie Ã¼ber den Deal wissen          507
# efa-109751 | Elektrischer China-Golf im Leasing: Der MG MG4 kostet unter 200 Euro pro Monat          490
# efa-1012593 | Cupra Born fÃ¼r Privatkunden mit garantierte BAFA-PrÃ¤mie bei Bestellung bis 19.05     488
#                                                                                                     ...
# efa-1017558 | KÃ¶nnen Verbraucher darauf hoffen? Das taugt Biomethan fÃ¼r die Heizung in Zukunft       1
# efa-109736 | Was passiert, wenn E-Autos ins Wasser fallen? Tesla-Funktion Ã¼berrascht                  1
# efa-1011434 | Nachhaltig bauen: So gelingt die ressourcenschonende Planung Ihres Eigenheims            1
# efa-1017567 | Deutsche Stadt sucht FlÃ¤chen fÃ¼r Solaranlagen: Hier sollten sie niemanden stÃ¶ren      1
# efa-1018511 | StraÃŸe fÃ¼rs E-Auto umgebaut: So sieht sie jetzt aus                                    1
# Name: count, Length: 6892, dtype: int64

# %%
df[["page_efahrer_id", "page_name"]].drop_duplicates().groupby("page_name").count()
# Out:
#                                                     page_efahrer_id
# page_name
# efa-1010012 | Hersteller reduziert fast alle So...                1
# efa-1010022 | Beliebter Irrglaube: Warum PV-Anl...                1
# efa-1010045 | Kleiner Aufkleber auf dem Rad: Di...                1
# efa-1010048 | Kann Solarstrom fÃ¼r den Winter s...                1
# efa-1010057 | Dreimal schneller zu FuÃŸ: Genial...                1
# ...                                                             ...
# efa-109925 | E-Bikes und E-Roller bei Hagebau.de                  1
# efa-109934 | E-Bike-Umbau-Kit soll in 30 Sekund...                1
# efa-109968 | TschÃ¼ss, Photovoltaik? Diese Sola...                1
# efa-109971 | Top 10: Diese E-Bike-Marken fahren...                1
# efa-109978 | Alte Anlagen werden jetzt Schrott:...                1
#
# [6892 rows x 1 columns]

# %%
df.groupby("page_efahrer_id").count()
# Out:
#                  date  published_at  publish_date_equal_to_date
# page_efahrer_id
# 1037                7             7                           7  \
# 1039                2             2                           2
# 1040               10            10                          10
# 10245               3             0                           3
# 10273              26            25                          26
# ...               ...           ...                         ...
# 1018763             1             0                           1
# 1018764             1             0                           1
# 1018766             1             0                           1
# 1018767             1             0                           1
# 1018768             1             0                           1
#
#                  page_canonical_url  page_name  classification_product
# page_efahrer_id
# 1037                              7          7                       7  \
# 1039                              2          2                       2
# 1040                             10         10                      10
# 10245                             3          3                       3
# 10273                            26         26                      26
# ...                             ...        ...                     ...
# 1018763                           1          1                       0
# 1018764                           1          1                       0
# 1018766                           1          1                       0
# 1018767                           1          1                       0
# 1018768                           1          1                       0
#
#                  classification_type  title  page_author  daily_likes
# page_efahrer_id
# 1037                               7      7            7            7  \
# 1039                               2      2            2            2
# 1040                              10     10           10           10
# 10245                              3      3            3            0
# 10273                             26     26           26           25
# ...                              ...    ...          ...          ...
# 1018763                            0      1            1            0
# 1018764                            0      1            1            0
# 1018766                            0      1            1            0
# 1018767                            0      1            1            0
# 1018768                            0      1            1            0
#
#                  daily_dislikes  word_count  video_play  clickouts
# page_efahrer_id
# 1037                          7           7           7          7  \
# 1039                          2           2           2          2
# 1040                         10          10          10         10
# 10245                         0           0           3          3
# 10273                        25          25          26         26
# ...                         ...         ...         ...        ...
# 1018763                       0           0           1          1
# 1018764                       0           0           1          1
# 1018766                       0           0           1          1
# 1018767                       0           0           1          1
# 1018768                       0           0           1          1
#
#                  discover_clicks  discover_impressions  day_of_week
# page_efahrer_id
# 1037                           7                     7            7  \
# 1039                           2                     2            2
# 1040                          10                    10           10
# 10245                          3                     3            3
# 10273                         26                    26           26
# ...                          ...                   ...          ...
# 1018763                        1                     1            1
# 1018764                        1                     1            1
# 1018766                        1                     1            1
# 1018767                        1                     1            1
# 1018768                        1                     1            1
#
#                  is_weekend  datetime
# page_efahrer_id
# 1037                      7         7
# 1039                      2         2
# 1040                     10        10
# 10245                     3         3
# 10273                    26        26
# ...                     ...       ...
# 1018763                   1         1
# 1018764                   1         1
# 1018766                   1         1
# 1018767                   1         1
# 1018768                   1         1
#
# [6891 rows x 19 columns]

# %%
df['page_efahrer_id'].value_counts()
# Out:
# page_efahrer_id
# 1014301    566
# 105259     561
# 1012150    507
# 109751     490
# 1012593    488
#           ...
# 1011281      1
# 1017558      1
# 109736       1
# 1011434      1
# 1018511      1
# Name: count, Length: 6891, dtype: int64

# %%
df[["page_efahrer_id", "page_name"]].drop_duplicates().groupby("page_name").count().max()
# Out:
# page_efahrer_id    1
# dtype: int64
